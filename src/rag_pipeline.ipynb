# %%
import google.generativeai as genai
from google.colab import userdata

api_key = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=api_key)

# %%
import json
import os

# %%
def load_json_files(folder_path='/content/data'):
  data = []
  for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
      file_path = os.path.join(folder_path, filename)
      with open(file_path, 'r', encoding='utf-8') as f:
        try:
          data.append(json.load(f))
        except json.JSONDecodeError as e:
          print(f"Error decoding JSON in file {filename}: {e}")
  return data

# %%
data = load_json_files()
print(data)
print(type(data))
print(len(data))
# Out:
# [{'chunks': [{'chunk_id': '1', 'document_type': 'Citizenship', 'section': '1', 'subsection': 'none', 'tag': ['eligibility & requirements', 'procedure'], 'references': [], 'content': 'यदि कुनै व्यक्ति अविवाहित छन् र वंशजको आधारमा नेपाली नागरिकता प्राप्त गर्न चाहन्छन् भने, निम्न प्रक्रिया र कागजातहरू आवश्यक पर्छन्:\nक. अनुसूचि-१ फाराममा वडा अध्यक्षको सिफारिश र सो मा टाँस भए जस्ते फोटो\nख. जन्मदर्ता वा नावालक परिचय पत्र (विद्यार्थीको हकमा सर्टिफिकेट समेत)\nग. वसाई सरी आएको भए सम्बन्धित वडाको स्थानीय पञ्जिलाधिकारीको कार्यालयबाट जारी वसाईसराई प्रमाणपत्र\nघ. विवरण फरक भए सो को सिफारिश पत्र\nङ. उमेर वढी पुगेका निवेदकहरुको हकमा वडा मुचुल्का {आवश्यकता परे यस कार्यालयबाट प्रहरी वुझिने छ}\nच. वुवा र आमाको नागरिकता (बुवा/आमाको मृत्यु भएको हकमा मृत्यु दर्ता प्र.प.)\nछ. बुवा/आमाबाट सनाखत (एकाघरका तिन पुस्ता भित्रका अन्य सदस्यबाट सनाखत गर्नु पर्ने हकमा नाता खुल्ने कागजात/नाता प्रमाणित प्रमाण-पत्र)'}, {'chunk_id': '2', 'document_type': 'Citizenship', 'section': '2', 'subsection': 'none', 'tag': ['special case', 'eligibility & requirements'], 'references': ['1'], 'content': 'यदि कुनै व्यक्ति अविवाहित छन् र कर्मचारी परिवारको आधारमा वंशजको नागरिकता प्राप्त गर्न चाहन्छन् भने, निम्न प्रक्रिया र कागजातहरू आवश्यक पर्छन्:\nक. माथी सि.नं. १ मा उल्लेखित सवै प्रकृया (कर्मचारी कार्यरत रहेको कार्यालय जुन वडामा छ सो वडा कार्यालयबाट प्रमाणित अनुसूचि थान २)\nख. सम्बन्धित कर्मचारीको कर्मचारी परिचय पत्र।\nग. यस जिल्लामा कार्यरत नेपाल सरकारको स्थायी कर्मचारी, सरकारी संस्थान, विश्वविद्यालय वा सामुदायिक विद्यालयमा कार्यरत शिक्षकको परिवार भएको भनी सम्बन्धित निकायले गरेको सिफारिश पत्र।'}, {'chunk_id': '3', 'document_type': 'Citizenship', 'section': '3', 'subsection': 'none', 'tag': ['eligibility & requirements', 'procedure'], 'references': [], 'content': 'यदि कुनै विवाहित महिला वंशजको आधारमा नेपाली नागरिकता प्राप्त गर्न चाहन्छिन् भने, निम्न प्रक्रिया र कागजातहरू आवश्यक पर्छन्:\nक. अनुसूचि-१ फाराममा वडा अध्यक्षको सिफारिश र सो मा टाँस भए जस्ते फोटो २ प्रति\nख. जन्मदर्ता वा नावालक परिचयपत्र (विद्यार्थीको हकमा शैक्षिक यो. को प्रमाण पत्र समेत)\nछ. माईती घरको वुवा/आमा/दाजु/भाईको नागरिकता (बुवा/आमाको मृत्यु भएको हकमा मृत्यु दर्ता प्रमाण पत्र)\nग. वसाई सरी आएको भए पञ्जिलाधिकारीको कार्यालयबाट जारी वसाईसराई प्रमाण पत्र\nज. पतिको ना. प्र.प्र. र सनाखत (पतिको मृत्यू भएको हकमा मृत्यु दर्ता प्र.प.)\nघ. उमेर वढी पुगेका निवेदकहरुको हकमा वडा मुचुल्का (पती वाहेक एकाघरका अन्य सदस्य सासु/ससुरा/जेठाजु/देवरबाट सनाखत)\nङ. विवरण फरक भए सो को सिफारिश पत्र गराउनु पर्ने हकमा निवेदकसँग नाता प्रमाणित भएको प्रमाण-पत्र र पती\nच. विवाह दर्ता प्रमाण-पत्र\nछ. पती उपस्थित हुन नसक्नुको कारण सहितको स्थानीय तहको सिफारिश पत्र'}, {'chunk_id': '4', 'document_type': 'Citizenship', 'section': '4', 'subsection': 'none', 'tag': ['special case', 'eligibility & requirements'], 'references': ['3', '3.ज'], 'content': 'यदि कुनै विवाहित महिला कर्मचारी परिवारको आधारमा वंशजको नागरिकता प्राप्त गर्न चाहन्छिन् भने, निम्न प्रक्रिया र कागजातहरू आवश्यक पर्छन्:\nक. माथी सि.नं. ३ मा उल्लेखित सवै प्रकृया (अनुसूचि प्रमाणित गर्ने हकमा कर्मचारी कार्यरत कार्यालय जुन वडामा छ सो वडा कार्यालयबाट प्रमाणित गरिएको २ थान अनुसूचि)\nख. ३ को ज नं. को हकमा पतिको सनाखत अनिवार्य\nग. कैलाली जिल्लामा कार्यरत नेपाल सरकारको स्थायी कर्मचारी, सरकारी संस्थान, विश्वविद्यालय वा सामुदायिक विद्यालयमा कार्यरत शिक्षकको परिवार भएको भनी सम्बन्धित निकायले गरेको सिफारिश पत्र\nघ. सम्बन्धित कर्मचारीको कर्मचारी परिचय पत्र।'}, {'chunk_id': '5', 'document_type': 'Citizenship', 'section': '5', 'subsection': 'none', 'tag': ['eligibility & requirements', 'procedure'], 'references': [], 'content': 'यदि कुनै विदेशी महिलाले नेपाली नागरिकसँग विवाह गरेकी छन् र अंगिकृत नागरिकता प्राप्त गर्न चाहन्छिन् भने, निम्न प्रक्रिया र कागजातहरू आवश्यक पर्छन्:\nक. अनुसूचि-७ को फाराममा वडा अध्यक्षको सिफारिश र सो मा टाँस भए जस्ते फोटो ३ प्रति\nच. विवरण फरक भए सो को सिफारिश पत्र\nख. विवाह दर्ता प्रमाण-पत्र\nछ. विदेशी नागरिकता परित्याग गर्न कारवाही चलाएको निस्सा/प्रमाण\nग. जन्म स्थान र जन्म मिति खुल्ने प्रमाण (विद्यार्थीको हकमा शैक्षिक योग्यताको प्र.प. समेत)\nज. पतिको ना.प्र.प. र सनाखत (पति ...
# <class 'list'>
# 2

# %%
from sentence_transformers import SentenceTransformer

# %%
mpnet_model = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')
labse_model = SentenceTransformer("sentence-transformers/LaBSE")
stn_model = SentenceTransformer("Yunika/sentence-transformer-nepali")
nem_model = SentenceTransformer("universalml/Nepali_Embedding_Model")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/165 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/692 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/950M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/201 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %%
import chromadb

# %%
class MultilingualEmbeddingFunction(chromadb.EmbeddingFunction):
  def __init__(self, embedding_model):
    self.model = embedding_model

  def __call__(self, input: chromadb.Documents)-> chromadb.Embeddings:
    embeddings = self.model.encode(input)
    return embeddings.tolist()

# %%
from typing import List

def create_collection(documents: List, path: str, name: str, embedding_model):
  client = chromadb.PersistentClient(path=path)
  embedding_function = MultilingualEmbeddingFunction(embedding_model)

  try:
    collection = client.create_collection(name=name, embedding_function=embedding_function)
    k=0
    for i in range(len(documents)):
      for j in range(documents[i]["total_chunks"]):
        k = k+1
        collection.add(documents=documents[i]["chunks"][j]["content"], ids=str(k))
    return collection

  except Exception as e:
    print(f"Error creating collection: {e}")

# %%
def load_collection(path:str, name:str, embedding_model):
  client = chromadb.PersistentClient(path=path)
  collection = client.get_collection(name=name, embedding_function=MultilingualEmbeddingFunction(embedding_model))
  return collection

# %%
def get_relevant_chunks(query: str, db, n_results: int=3):
  results = db.query(query_texts=[query], n_results=n_results, include=["documents", "distances", "metadatas"])
  return results

# %%
def rag_prompt(query: str, relevant_chunks: List[str]):
  context = "\n\n".join([f'''PASSAGE {i+1}:{p.replace("'", "").replace('"', '').strip()}''' for i, p in enumerate(relevant_chunks)])
  return f"""
  You are a helpful AI assistant that answers questions about Nepali government document processes
  (such as citizenship, passport, and birth certificates).

  Follow these rules strictly:

  1. Answer *only* using the provided context.
  2. If the answer is not directly given, you may *infer it indirectly* from related information in the context —
    but only if the inference is *logical and clearly supported* by the context.
    - Note: These are legal/government documents, so you must be extremely careful when inferring answers.
  3. If neither direct nor reasonable indirect inference is possible, reply exactly:
    "मलाई थाहा छैन।"  (I don’t know.)

  *CRITICAL FORMATTING RULES:*
  - Keep answers *concise*
  - Make sure answer is not vague try to resolve vagueness
  - Use bullet points only when necessary
  - Use *simple and clear language*

  *Answer Style Guide:*
  - *Document lists:* Very short bullet points
  - *Procedures:* Minimal step-by-step format
  - *Definitions:* One clear sentence
  - *Requirements:* Minimal list or short sentence

  QUESTION: {query}
  CONTEXT:
  {context}
  ANSWER:
  """

# %%
def generate_response(db, query:str):
  relevant_chunks = get_relevant_chunks(query, db)['documents'][0]
  # print(f"Relevant Chunks: {relevant_chunks}")
  prompt = rag_prompt(query, relevant_chunks)
  model = genai.GenerativeModel("gemini-2.5-flash")
  try:
    response = model.generate_content(prompt)
    return response.text
  except Exception as e:
    return f"Error generating response: {str(e)}"

# %%
db_paths = ['/content/db_mpnet', '/content/db_labse', '/content/db_nem', '/content/db_stn']
embedding_models = [mpnet_model, labse_model, nem_model, stn_model]
dbs =[]
for i, db_path in enumerate(db_paths):
  os.makedirs(db_path, exist_ok=True)
  collection_name = 'collection'

  db = create_collection(data, db_path, collection_name, embedding_models[i])
  print("DB created successfully")
  print(f"Collection contains {db.count()} items")
  dbs.append(db)
# Out:
# DB created successfully
# Collection contains 58 items
# DB created successfully
# Collection contains 58 items
# DB created successfully
# Collection contains 58 items
# DB created successfully
# Collection contains 58 items

# %%
qa_pairs = load_json_files(folder_path='/content/qa')
print(qa_pairs)
# Out:
# [{'citizenship_qa': [{'question': 'नेपाली नागरिकताको प्रमाणपत्र लिनका लागि कुन कार्यालयमा जानुपर्छ?', 'answer': 'नेपाली नागरिकताको प्रमाणपत्र लिनको लागि सम्बन्धित व्यक्तिले आफ्नो स्थायी ठेगानाको जिल्ला प्रशासन कार्यालय मा जानुपर्छ। तर त्यसअघि, वडा कार्यालयबाट जन्मस्थान र नाता खुल्ने सिफारिस लिनु अनिवार्य हुन्छ। वंशजको नागरिकताको हकमा अनुसूचि-१ फाराम मा वडा अध्यक्षले सिफारिस गरिदिनुपर्छ, जसमा टाँस फोटो पनि जोडिएको हुन्छ। यी कागजातहरू तयार पारेर जिल्ला प्रशासन कार्यालयमा निवेदन दिनुपर्छ।'}, {'question': 'यदि मसँग बाबु वा आमाको नागरिकताको प्रमाणपत्र नभएमा, सर्जमिनको आधारमा नागरिकता प्राप्त गर्न सकिन्छ कि सकिँदैन र त्यसमा कति जनाले सनाखत गर्नुपर्छ?', 'answer': 'हो, बाबु वा आमाको नागरिकता प्रमाणपत्र नभएमा स्थलगत सर्जमिनको आधारमा नागरिकता लिन सकिन्छ, तर त्यसका लागि सोही वडामा बसोबास गर्ने कम्तीमा तीनजना नेपाली नागरिकले सनाखत गर्नुपर्छ र वडा कार्यालयको सिफारिस पनि अनिवार्य हुन्छ।'}, {'question': 'जन्मस्थान र नाता खुल्ने सिफारिस कसले गरिदिएको हुनुपर्दछ?', 'answer': 'जन्मस्थान र नाता खुल्ने सिफारिस सम्बन्धित वडा कार्यालयका वडा अध्यक्षले गरिदिएको हुनुपर्छ। यो सिफारिस अनुसूचि-१ फाराममा तयार पारिन्छ, जसमा निवेदकको जन्म विवरण, स्थायी ठेगाना, र नाता सम्बन्ध स्पष्ट रूपमा उल्लेख गरिएको हुन्छ।'}, {'question': 'मैले १६ वर्ष उमेर पुगेपछि पनि कुनै विदेशी मुलुकको नागरिकता प्राप्त गरेमा मेरो नेपाली नागरिकता कायम राख्नको लागि कति समयभित्र नागरिकता रोज्नुपर्छ?', 'answer': 'यदि तपाईंले १६ वर्ष उमेर पुगेपछि विदेशी मुलुकको नागरिकता प्राप्त गर्नुभयो भने, तपाईंले दुई वर्षभित्र नेपाली वा विदेशीमध्ये कुन नागरिकता रोज्ने निर्णय गर्नुपर्छ। सो समयभित्र रोज्न नसकेमा तपाईंको नेपाली नागरिकता स्वतः समाप्त हुन्छ।'}, {'question': 'मेरो बच्चाको नागरिकता बनाउन जाँदा बुवा र आमा दुवै जना जानै पर्छ कि पर्दैन?', 'answer': 'बच्चाको नागरिकता बनाउन जाँदा सामान्यतः बुवा वा आमा मध्ये कम्तीमा एक जना उपस्थित भएर सनाखत गर्नुपर्छ। यदि दुबै जना उपस्थित हुन सक्दैनन् भने, एकाघरका तीन पुस्ताभित्रका नातेदार (जस्तै: हजुरबुवा, दाजु, भाई) ले नाता प्रमाणित कागजातसहित सनाखत गर्न सक्ने व्यवस्था छ। तर अनुपस्थितिको कारणसहितको वडा सिफारिस पनि अनिवार्य हुन्छ।'}, {'question': 'मेरो नागरिकताको प्रमाणपत्र कतै हरायो, अब त्यसको अर्को कपी (प्रतिलिपि) कसरी निकाल्न सकिन्छ?', 'answer': 'नागरिकताको प्रमाणपत्र हराएको अवस्थामा प्रतिलिपि निकाल्नको लागि प्रहरीमा मुचुल्का गराई, त्यसको प्रमाणसहित वडा कार्यालयबाट सिफारिस लिनुपर्छ। साथै, पुरानो नागरिकताको नम्बर वा विवरण खुल्ने कुनै प्रमाण, रु १३ को टिकट टाँस गरेर जिल्ला प्रशासन कार्यालयमा निवेदन दिनुपर्छ। सबै कागजातहरूको सक्कल प्रति अनिवार्य रूपमा पेश गर्नुपर्छ।'}, {'question': 'वंशजको नाताले नागरिकता प्राप्त गर्ने व्यक्तिको उमेर कति हुनुपर्छ र त्यसको प्रमाण के चाहिन्छ?', 'answer': 'वंशजको नाताले नागरिकता प्राप्त गर्नको लागि व्यक्तिको उमेर कम्तीमा १६ वर्ष पूरा भएको हुनुपर्छ। उमेर प्रमाणको रूपमा जन्मदर्ता प्रमाणपत्र वा नाबालक परिचयपत्र पेश गर्नुपर्छ, र विद्यार्थीको हकमा शैक्षिक प्रमाणपत्र पनि मान्य हुन्छ।'}, {'question': 'विवाहपछि श्रीमान्को थर राख्नका लागि नागरिकतामा भएको थर कसरी सच्याउने (संशोधन गर्ने)?', 'answer': 'विवाहपछि श्रीमान्को थर राख्नका लागि नागरिकता प्रमाणपत्रमा संशोधन गर्न विवाह दर्ता प्रमाणपत्र, वडा कार्यालयको सिफारिस, र पुरानो नागरिकताको प्रमाण पेश गरी जिल्ला प्रशासन कार्यालयमा निवेदन दिनुपर्छ। अधिकारीले प्रमाणको आधारमा पुरानो नागरिकता खिची नयाँ थरसहितको नागरिकता प्रमाणपत्र जारी गर्छन्।'}, {'question': 'मेरो शैक्षिक प्रमाणपत्र र नागरिकतामा मेरो जन्म मिति वा नाम फरक परेको छ, यसलाई कसरी मिलाउने (Correction गर्ने)?', 'answer': "नागरिकतामा थर वा उमेरको **'सानातिना त्रुटी'** सच्याउनका लागि **शैक्षिक योग्यताको प्रमाणपत्र** जस्ता आवश्यक **सबुत प्रमाण** र **वडा कार्यालयको सिफारिस** सहित जिल्ला प्रशासन कार्यालयमा निवेदन दिनुपर्छ। प्रमाण भिडेमा, अधिकारीले **पहिलेको नागरिकता फिर्ता लिएर** सच्याइएको नयाँ नागरिकता दिनेछन्।"}, {'question': 'नेपाली नागरिकसँग विवाह गरेकी विदेशी महिलाले अंगीकृत नागरिकता पाउनका लागि के-के कागजात चाहिन्छ?', 'answer': 'नेपाली नागरिकसँग वैवाहिक सम्बन्ध भएकी विदेशी महिलाले **विवाह दर्ता प्रमाण-पत्र** र आफूले **विदेशी नागरिकता त्याग्ने कारबाही चलाएको निस्सा (प्रमाण)** सहित **तोकिएको ढाँचा (अनुसूची-७)** मा जिल्ला प्रशासन कार्यालयमा निवेदन ...

# %%
print(qa_pairs[0]["citizenship_qa"][0]['question'])
# Out:
# नेपाली नागरिकताको प्रमाणपत्र लिनका लागि कुन कार्यालयमा जानुपर्छ?

# %%
questions = []
answers = []

for qa_pair in qa_pairs[0]["citizenship_qa"]:
  questions.append(qa_pair['question'])
  answers.append(qa_pair['answer'])

# %%
import time

filename = ["mpnet_response.json", "labse_response.json", "nem_response.json", "stn_response.json"]
for i in range(len(dbs)):
  qa_response = []
  for j in range(len(questions)):
    output = generate_response(dbs[i], questions[j])
    print(f"Answered {j+1} out of {len(questions)}")
    output_response_json = {
        'question': questions[j],
        'answer': output
    }
    qa_response.append(output_response_json)
    time.sleep(5)

  with open(filename[i], 'w', encoding="utf-8") as f:
    json.dump(qa_response, f, ensure_ascii=False, indent=4)
  print(f"Saved {filename[i]}")
  print("\n" + "="*50 + "\n")
# Out:
# Answered 1 out of 20
# Answered 2 out of 20
# Answered 3 out of 20
# Answered 4 out of 20
# Answered 5 out of 20
# Answered 6 out of 20
# Answered 7 out of 20
# Answered 8 out of 20
# Answered 9 out of 20
# Answered 10 out of 20
# Answered 11 out of 20
# Answered 12 out of 20
# Answered 13 out of 20
# Answered 14 out of 20
# Answered 15 out of 20
# Answered 16 out of 20
# Answered 17 out of 20
# Answered 18 out of 20
# Answered 19 out of 20
# Answered 20 out of 20
# Saved mpnet_response.json
#
# ==================================================
#
# Answered 1 out of 20
# Answered 2 out of 20
# Answered 3 out of 20
# Answered 4 out of 20
# Answered 5 out of 20
# Answered 6 out of 20
# Answered 7 out of 20
# Answered 8 out of 20
# Answered 9 out of 20
# Answered 10 out of 20
# Answered 11 out of 20
# Answered 12 out of 20
# Answered 13 out of 20
# Answered 14 out of 20
# Answered 15 out of 20
# Answered 16 out of 20
# Answered 17 out of 20
# Answered 18 out of 20
# Answered 19 out of 20
# Answered 20 out of 20
# Saved labse_response.json
#
# ==================================================
#
# Answered 1 out of 20
# Answered 2 out of 20
# Answered 3 out of 20
# Answered 4 out of 20
# Answered 5 out of 20
# Answered 6 out of 20
# Answered 7 out of 20
# Answered 8 out of 20
# Answered 9 out of 20
# Answered 10 out of 20
# Answered 11 out of 20
# Answered 12 out of 20
# Answered 13 out of 20
# Answered 14 out of 20
# Answered 15 out of 20
# Answered 16 out of 20
# Answered 17 out of 20
# Answered 18 out of 20
# Answered 19 out of 20
# Answered 20 out of 20
# Saved nem_response.json
#
# ==================================================
#
# Answered 1 out of 20
# Answered 2 out of 20
# Answered 3 out of 20
# Answered 4 out of 20
# Answered 5 out of 20
# Answered 6 out of 20
# Answered 7 out of 20
# Answered 8 out of 20
# Answered 9 out of 20
# Answered 10 out of 20
# Answered 11 out of 20
# Answered 12 out of 20
# Answered 13 out of 20
# Answered 14 out of 20
# Answered 15 out of 20
# Answered 16 out of 20
# Answered 17 out of 20
# Answered 18 out of 20
# Answered 19 out of 20
# Answered 20 out of 20
# Saved stn_response.json
#
# ==================================================

# %%
import matplotlib.pyplot as plt

idk_response = [12, 8, 6, 9]
labels = ['mpnet', 'labse', 'nem', 'stn']

plt.bar(labels, idk_response)
plt.title("I don't Know: Response Distribution")
plt.xlabel('Embedding Models')
plt.ylabel('Count out of 20')
plt.ylim(0, 20)
plt.show()

# %% [markdown]
# The evaluation used the following scoring criteria for each question:
#
# **1.0 (Fully Correct)**: The answer is factual, complete, and concise, matching the ground truth.
#
# **0.5 (Partially Correct)**: The answer contains important facts but misses key details or is incomplete.
#
# **0.0 (Incorrect / No Answer)**: The answer is factually wrong or the model responded with "I don't know" (indicating a failure to retrieve or generate).

# %%
correctness_score = [5.5, 11.5, 13, 10.5]

plt.bar(labels, correctness_score)
plt.title("Correctness Score")
plt.xlabel('Embedding Models')
plt.ylabel('Count out of 20')
plt.ylim(0, 20)
plt.show()
